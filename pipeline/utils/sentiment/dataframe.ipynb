# %%
"""
Conventions to follow :

1) Place the downloaded tweets(JSON files) on your desktop screen inside a folder named as "tweets_json".

Note : The conversion of coordinate to value takes some time to execute, Have Patience :P
   
"""
# Out:
# '\nConventions to follow :\n\n1) Place the downloaded tweets(JSON files) on your desktop screen inside a folder named as "tweets_json".\n\nNote : The conversion of coordinate to value takes some time to execute, Have Patience :P\n   \n'

# %%
# Importing libraries
import glob,os
import pandas as pd
from tqdm import tqdm_notebook
import numpy as np

import matplotlib.pyplot as plt
import utm
import math
from shapely.geometry import Point, Polygon

from twokenize3 import *
from sentiment import *

# %%
# Geospatial Grid
def generateGrid(coors, distance_offset):
    """ Getting the grids of 1000 meters square.
        parameters: minx, miny, maxx, maxy 
        returns: grid of the 
    """
    dx = distance_offset
    dy = distance_offset

    nx = int(math.ceil(abs(coors['up_right_x'] - coors['low_left_x'])/dx))
    ny = int(math.ceil(abs(coors['up_right_y'] - coors['low_left_y'])/dy))
    grid = []

    for i in range(ny):
        for j in range(nx):
            vertices = []
            vertices.append([coors['low_left_x']+dx*j,coors['low_left_y']+dy*i])
            vertices.append([coors['low_left_x']+dx*(j+1),coors['low_left_y']+dy*i])
            vertices.append([coors['low_left_x']+dx*(j+1),coors['low_left_y']+dy*(i+1)])
            vertices.append([coors['low_left_x']+dx*j,coors['low_left_y']+dy*(i+1)])
            grid.append(vertices)
            
    return grid

def pointInPolygon(point, polygons):
    pt = Point(point)
    for poly in polygons:
        pol = Polygon(poly)
        if(pol.contains(pt)):
            return(polygons.index(poly))
    return np.nan

# %%
# minimum and maximum X and Y coordinates to create the grid and the grid offset
def initialise_grid():    
    offset = 1000
    coors = {'low_left_x' : 421710.112401581, 'low_left_y' : 4610737.961457818, 'up_right_x' : 456608.39121255605, 'up_right_y' : 4652466.087380382}
    grid = generateGrid(coors, offset)
    return grid

# %%
# Creates hdf5 documents on the basis of c2v values
def makeDocuments(c2v_values,dataset):
    desktop_path = os.path.join(os.path.join(os.path.expanduser('~')), 'Desktop')
    os.chdir(desktop_path)
    directory = "hdf5_Doc"
    if not os.path.exists(directory):
        os.makedirs(directory)
    os.chdir(desktop_path + "/" + directory)
    for values in c2v_values:
        doc = dataset[dataset["c2v"] == values]
        filename = str(values) + ".hdf5"
        doc.reset_index(drop=True)
        doc.to_hdf(filename,'key')

# %%
# Processing dataframe
def create_dataframe():
    desktop_path = os.path.join(os.path.join(os.path.expanduser('~')), 'Desktop')
    tweets_path = desktop_path + "/tweets_json/*.json"
    tweets = pd.concat(map(pd.read_json, tqdm_notebook(glob.glob(tweets_path))))
    return tweets

# Removing the null values from the input dataframe
def filter_dataframe(data):
    # coordinates = longitude
    # geo = lattitude
    headers = ["geo", "text","lang","timestamp_ms"]
    df = data[headers]
    for columns in headers:
        df = df[df[columns].notnull()]
    # Considering the tweets only in english language
    return df[df["lang"] == "en"].reset_index(drop=True)

# Converts the coordinates to their respective grid index
def c2v(dataset):
    c2v_list = []
    grid = initialise_grid()
    for index,values in enumerate(dataset["geo"]):
        pt = utm.from_latlon(values["coordinates"][0],values["coordinates"][1])[0:2]
        # Coordinate to value function
        c2v_list.append(pointInPolygon(pt, grid))
    dataset["c2v"] = c2v_list
    return dataset

# %%
# Initialising dataframe
def initialise_dataframe():
    df = create_dataframe()
    df = filter_dataframe(df)
    return df

# Process the dataframe to get sentiment and tokenized values
def process_dataframe(dataset):
    myDic = {}
    tweetList,temp = ([] for i in range(2))
    dataset = c2v(dataset)
    dataset["sentiment_text"] = dataset["text"].apply(findSentimentTweet)
    dataset["twokenized_text"] = dataset["text"].apply(tokenizeRawTweetText)
    dataset.dropna(inplace=True)
    dataset.sort_values(['c2v'],inplace=True)
    dataset["c2v"] = dataset["c2v"].astype(int)
    c2v_list = dataset["c2v"].unique()
    makeDocuments(c2v_list,dataset)
    desktop_path = os.path.join(os.path.join(os.path.expanduser('~')), 'Desktop')
    directory = desktop_path + "/" + "hdf5_Doc"
    for filename in os.listdir(os.getcwd()):
        if filename.endswith(".hdf5"):
            doc = pd.read_hdf(filename)
            for values in doc["text"]:
                temp.append(values)
                tweetList.append(temp)
            myDic[str(filename)] = findSentimentDoc(tweetList[-1])
        else:
            pass
    return dataset,myDic

# %%
def final_function():
    df = initialise_dataframe()
    df,myDict = process_dataframe(df)
    return df,myDict

# %%
df,myDict = final_function()
# Out:
# A Jupyter Widget
# /home/suzane/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:1299: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->['geo', 'text', 'lang', 'twokenized_text']]
#
#   return pytables.to_hdf(path_or_buf, key, self, **kwargs)

# %%
df
# Out:
#                                                      geo  \
# 1644   {'type': 'Point', 'coordinates': [41.6545, -87...
# 10498  {'type': 'Point', 'coordinates': [41.64943326,...
# 9230   {'type': 'Point', 'coordinates': [41.65160259,...
# 2665   {'type': 'Point', 'coordinates': [41.64943326,...
# 7452   {'type': 'Point', 'coordinates': [41.6497, -87...
# 3895   {'type': 'Point', 'coordinates': [41.6499, -87...
# 1575   {'type': 'Point', 'coordinates': [41.65462, -8...
# 555    {'type': 'Point', 'coordinates': [41.6497, -87...
# 2271   {'type': 'Point', 'coordinates': [41.6490841, ...
# 2459   {'type': 'Point', 'coordinates': [41.65077, -8...
# 2264   {'type': 'Point', 'coordinates': [41.6490841, ...
# 9599   {'type': 'Point', 'coordinates': [41.6497, -87...
# 2776   {'type': 'Point', 'coordinates': [41.65068368,...
# 11134  {'type': 'Point', 'coordinates': [41.649024, -...
# 10843  {'type': 'Point', 'coordinates': [41.65039607,...
# 10352  {'type': 'Point', 'coordinates': [41.655423, -...
# 7413   {'type': 'Point', 'coordinates': [41.6626, -87...
# 9088   {'type': 'Point', 'coordinates': [41.65524735,...
# 7730   {'type': 'Point', 'coordinates': [41.6611444, ...
# 10277  {'type': 'Point', 'coordinates': [41.6611444, ...
# 5396   {'type': 'Point', 'coordinates': [41.6611444, ...
# 163    {'type': 'Point', 'coordinates': [41.6611444, ...
# 8419   {'type': 'Point', 'coordinates': [41.66276572,...
# 8900   {'type': 'Point', 'coordinates': [41.6584, -87...
# 10684  {'type': 'Point', 'coordinates': [41.6572562, ...
# 4779   {'type': 'Point', 'coordinates': [41.66270496,...
# 11669  {'type': 'Point', 'coordinates': [41.66291, -8...
# 906    {'type': 'Point', 'coordinates': [41.66271, -8...
# 6108   {'type': 'Point', 'coordinates': [41.66271, -8...
# 7759   {'type': 'Point', 'coordinates': [41.66271, -8...
# ...                                                  ...
# 7300   {'type': 'Point', 'coordinates': [42.01914809,...
# 2804   {'type': 'Point', 'coordinates': [42.0162733, ...
# 9812   {'type': 'Point', 'coordinates': [42.022177, -...
# 5256   {'type': 'Point', 'coordinates': [42.0189191, ...
# 6348   {'type': 'Point', 'coordinates': [42.0189191, ...
# 5433   {'type': 'Point', 'coordinates': [42.0189191, ...
# 6111   {'type': 'Point', 'coordinates': [42.0189191, ...
# 3878   {'type': 'Point', 'coordinates': [42.0189191, ...
# 8403   {'type': 'Point', 'coordinates': [42.0189191, ...
# 3362   {'type': 'Point', 'coordinates': [42.0189191, ...
# 4524   {'type': 'Point', 'coordinates': [42.0189191, ...
# 6424   {'type': 'Point', 'coordinates': [42.0189191, ...
# 11575  {'type': 'Point', 'coordinates': [42.0189191, ...
# 6546   {'type': 'Point', 'coordinates': [42.0189191, ...
# 11631  {'type': 'Point', 'coordinates': [42.0189191, ...
# 7401   {'type': 'Point', 'coordinates': [42.0189191, ...
# 3557   {'type': 'Point', 'coordinates': [42.0189191, ...
# 1297   {'type': 'Point', 'coordinates': [42.0219595, ...
# 5719   {'type': 'Point', 'coordinates': [42.0219595, ...
# 7190   {'type': 'Point', 'coordinates': [42.015597, -...
# 1102   {'type': 'Point', 'coordinates': [42.02104171,...
# 1111   {'type': 'Point', 'coordinates': [42.015597, -...
# 4325   {'type': 'Point', 'coordinates': [42.0206, -87...
# 6714   {'type': 'Point', 'coordinates': [42.01939, -8...
# 7635   {'type': 'Point', 'coordinates': [42.019646, -...
# 2415   {'type': 'Point', 'coordinates': [42.0192147, ...
# 3306   {'type': 'Point', 'coordinates': [42.0192147, ...
# 6396   {'type': 'Point', 'coordinates': [42.016, -87....
# 4283   {'type': 'Point', 'coordinates': [42.01920817,...
# 774    {'type': 'Point', 'coordinates': [42.01634, -8...
#
#                                                     text lang  \
# 1644   Light fresh beef. But the after taste just as ...   en
# 10498  Feels good to be back at my gym since 2012; Da...   en
# 9230   #BlackPanther @ AMC Theatre-Crestwood 18 https...   en
# 2665   Sunday Cardio Sessions - on the bike 🏍 listeni...   en
# 7452   Candie sugars not too sweet ..slight vanilla.....   en
# 3895   Mash behaving like a good sour mash should! @ ...   en
# 1575   THE AFTER PARTY IS IN ACTION AT club_krave!!! ...   en
# 555    Hey  at a book signing 4 @bobbyskafish with a ...   en
# 2271   Next sat will be lit showtime 7pm don’t be lat...   en
# 2459   I went out alone last night. I caught up on em...   en
# 2264   Random next Saturday I’m hosting at Island bar...   en
# 9599   On Nitro..... - Drinking a Hard Luck IPA by @b...   en
# 2776   Bartenders night off (@ Rock Island Public Hou...   en
# 11134  Next sat at the @ISLANDBAR_GRILL will be super...   en
# 10843  I'm at Esparza's Restaurant in Blue Island, IL...   en
# 10352  Chicago, I want to have FUN tonight! What is F...   en
# 7413   Drinking a Beer Simply Beer Ipa by @Midwestbre...   en
# 9088   Pioneer kickoff classic, conor_wolf2 the strea...   en
# 7730   If you're looking for work in #Crestwood, IL, ...   en
# 10277  See our latest #Crestwood, IL #job and click t...   en
# 4325   [More, malty, than, citrusy, ., Still, a, guuu...
# 6714   [TONIGHT, DECEMBER, 8th, ...., REGGAE, FRIDAYS...
# 7635   [I'm, at, @IHOP, in, Evanston, ,, IL, https://...
# 2415   [If, you're, looking, for, work, in, #Chicago,...
# 3306   [Interested, in, a, #job, in, #Chicago, ,, IL,...
# 6396   [Yomz, -, Drinking, an, Ottermelon, Gose, by, ...
# 4283   [Christmas, party, in, my, apartment, ., Guess...
# 774    [#gameday, #sundayfunday, #greenbaypackers, #w...
#
# [7976 rows x 7 columns]

# %%
myDict
# Out:
# {'1000.hdf5': -0.14265829994858492,
#  '1001.hdf5': -0.14943281550036017,
#  '1002.hdf5': -0.15434988273368022,
#  '1003.hdf5': -0.1521483259531615,
#  '1004.hdf5': -0.15575132732976954,
#  '1005.hdf5': -0.141143204247339,
#  '1006.hdf5': -0.15565735898861713,
#  '1015.hdf5': -0.14756312175868425,
#  '1018.hdf5': -0.14034448557248091,
#  '1019.hdf5': -0.15099338250107108,
#  '102.hdf5': -0.1424163049911238,
#  '1021.hdf5': -0.15477059314276204,
#  '1022.hdf5': -0.11941736553374938,
#  '1023.hdf5': -0.15543424703208056,
#  '1024.hdf5': -0.15568929864391046,
#  '1026.hdf5': -0.1543505108796985,
#  '1030.hdf5': -0.15567761627118118,
#  '1031.hdf5': -0.14934271192283155,
#  '1034.hdf5': -0.14823480617047421,
#  '1035.hdf5': -0.15146185592944955,
#  '1036.hdf5': -0.14912540845202663,
#  '1037.hdf5': -0.1550206743415555,
#  '1038.hdf5': -0.15580090907603128,
#  '1039.hdf5': -0.15010310110026162,
#  '1040.hdf5': -0.14282050008379937,
#  '1041.hdf5': -0.15572049031016535,
#  '1053.hdf5': -0.15494845060126658,
#  '1054.hdf5': -0.14578762781601012,
#  '1056.hdf5': -0.1520735326699316,
#  '1058.hdf5': -0.1429562092888063,
#  '1060.hdf5': -0.1521145377712989,
#  '1061.hdf5': -0.11477137474256181,
#  '1062.hdf5': -0.15485685412297162,
#  '1065.hdf5': -0.15200642808443673,
#  '1066.hdf5': -0.14822513963588174,
#  '1067.hdf5': -0.15494065534003937,
#  '1068.hdf5': -0.15004964937748563,
#  '1069.hdf5': -0.1547926940830256,
#  '1070.hdf5': -0.14824342677640817,
#  '1071.hdf5': -0.1424700410364962,
#  '1072.hdf5': -0.1542071393463944,
#  '1073.hdf5': -0.1485897754737139,
#  '1074.hdf5': -0.1946804269929694,
#  '1075.hdf5': -0.149510875173687,
#  '1076.hdf5': -0.15488957020907868,
#  '1089.hdf5': -0.14960738984198726,
#  '1093.hdf5': -0.19376997808359572,
#  '1096.hdf5': -0.14909703715821376,
#  '1097.hdf5': -0.15105492935038672,
#  '1100.hdf5': -0.15284971596679162,
#  '1101.hdf5': -0.154887170054762,
#  '1102.hdf5': -0.15009738110166324,
#  '1104.hdf5': -0.14819296902398976,
#  '1105.hdf5': -0.14859669338579704,
#  '1106.hdf5': -0.1433220897368794,
#  '1107.hdf5': -0.1471976714802559,
#  '1108.hdf5': -0.14797485736387866,
#  '1109.hdf5': -0.14263077847149122,
#  '1110.hdf5': -0.15471106346247754,
#  '1120.hdf5': -0.15396949106465596,
#  '1123.hdf5': -0.1494367766246925,
#  '1125.hdf5': -0.1456534944237765,
#  '1131.hdf5': -0.1558607113407832,
#  '1133.hdf5': -0.15215238466833905,
#  '1134.hdf5': -0.1491381178721259,
#  '1135.hdf5': -0.15111225514157547,
#  '1136.hdf5': -0.14931968578803445,
#  '1137.hdf5': -0.14845694742007381,
#  '1138.hdf5': -0.120547975665047,
#  '1139.hdf5': -0.14554200286592442,
#  '1140.hdf5': -0.14290228676494027,
#  '1141.hdf5': -0.14184065072331414,
#  '1142.hdf5': -0.14276715173445623,
#  '1143.hdf5': -0.142498895542925,
#  '1144.hdf5': -0.15474914319959332,
#  '1145.hdf5': -0.14794172867651872,
#  '1156.hdf5': -0.154869542570209,
#  '1160.hdf5': -0.148767538818093,
#  '1166.hdf5': -0.14790695356285152,
#  '1167.hdf5': -0.15115562716639802,
#  '1170.hdf5': -0.14556622106510342,
#  '1171.hdf5': -0.15514390350228682,
#  '1172.hdf5': -0.15217962409956168,
#  '1174.hdf5': -0.15169647994890956,
#  '1175.hdf5': -0.1546080779723832,
#  '1176.hdf5': -0.1548947961170156,
#  '1177.hdf5': -0.14856342112914667,
#  '1178.hdf5': -0.14783486152821584,
#  '1179.hdf5': -0.146605823787464,
#  '1180.hdf5': -0.14248543297342808,
#  '1190.hdf5': -0.1550784495738094,
#  '1192.hdf5': -0.14185813451077234,
#  '1196.hdf5': -0.15009286507541728,
#  '1197.hdf5': -0.1264177413702187,
#  '1199.hdf5': -0.15565088321800816,
#  '1201.hdf5': -0.15559305785120287,
#  '1202.hdf5': -0.15511387526031556,
#  '1203.hdf5': -0.15572437522910387,
#  '1204.hdf5': -0.1486454532566963,
#  '1205.hdf5': -0.15411922813767281,
#  '1206.hdf5': -0.14906571074087835,
#  '1207.hdf5': -0.1538774556371805,
#  '1208.hdf5': -0.15236582434469773,
#  '1209.hdf5': -0.14918535503381358,
#  '1210.hdf5': -0.14820237155757485,
#  '1211.hdf5': -0.1467108030263249,
#  '1212.hdf5': -0.14735153072332186,
#  '1213.hdf5': -0.14847353523311224,
#  '1214.hdf5': -0.14371450963284266,
#  '1227.hdf5': -0.14785514698710386,
#  '1229.hdf5': -0.14871573942449456,
#  '123.hdf5': -0.1521368911476204,
#  '1234.hdf5': -0.14826651363489052,
#  '1236.hdf5': -0.14923929817982348,
#  '1239.hdf5': -0.14062108779483518,
#  '1240.hdf5': -0.1551216356901446,
#  '1241.hdf5': -0.15441821609096526,
#  '1242.hdf5': -0.1486981686121694,
#  '1243.hdf5': -0.1558112400053046,
#  '1244.hdf5': -0.12492991667029367,
#  '1245.hdf5': -0.15184020746023144,
#  '1246.hdf5': -0.14958180580731556,
#  '1247.hdf5': -0.1495179894950642,
#  '1248.hdf5': -0.14235925193780447,
#  '1249.hdf5': -0.14761160920153601,
#  '1250.hdf5': -0.1487012352186964,
#  '1262.hdf5': -0.13977791000433348,
#  '1263.hdf5': -0.15568145822507512,
#  '1264.hdf5': -0.15443490763427128,
#  '1266.hdf5': -0.15572736179293273,
#  '1268.hdf5': -0.15587491240931353,
#  '1271.hdf5': -0.15137804299083535,
#  '1272.hdf5': -0.1560236871596668,
#  '1274.hdf5': -0.14678871392342788,
#  '1275.hdf5': -0.14294275096790166,
#  '1276.hdf5': -0.14939804384191618,
#  '1279.hdf5': -0.14290853264741227,
#  '128.hdf5': -0.15514662115822392,
#  '1280.hdf5': -0.15531694042719382,
#  '1281.hdf5': -0.15560778239255263,
#  '1282.hdf5': -0.14947024308885784,
#  '1283.hdf5': -0.15555437372336897,
#  '1297.hdf5': -0.15211048670788826,
#  '1298.hdf5': -0.1490935321267583,
#  '130.hdf5': -0.15556767426550155,
#  '1301.hdf5': -0.154303988177018,
#  '1302.hdf5': -0.14832932914350735,
#  '1303.hdf5': -0.15102331568358365,
#  '1304.hdf5': -0.15466887552346523,
#  '1306.hdf5': -0.1498584098341447,
#  '1307.hdf5': -0.15582967366720255,
#  '1309.hdf5': -0.14995408135876012,
#  '131.hdf5': -0.14071402991561413,
#  '1310.hdf5': -0.1490093249016774,
#  '1311.hdf5': -0.14837763757910566,
#  '1312.hdf5': -0.14956964727892855,
#  '1313.hdf5': -0.15556124041038158,
#  '1315.hdf5': -0.14093230217327535,
#  '1316.hdf5': -0.15610201801083695,
#  '1317.hdf5': -0.14989643600313973,
#  '1318.hdf5': -0.15483868505401935,
#  '1319.hdf5': -0.14015753662489003,
#  '1335.hdf5': -0.15597843831257904,
#  '1336.hdf5': -0.14884203415996242,
#  '1337.hdf5': -0.14891892769923049,
#  '1340.hdf5': -0.14926958100158974,
#  '1341.hdf5': -0.1468200976713759,
#  '1343.hdf5': -0.14850643307851888,
#  '1345.hdf5': -0.14845767308833283,
#  '1346.hdf5': -0.15489081437297608,
#  '1347.hdf5': -0.1488362915642276,
#  '1348.hdf5': -0.14846850241426024,
#  '1349.hdf5': -0.1547384670410006,
#  '1350.hdf5': -0.1436866308960091,
#  '1351.hdf5': -0.12847280023510918,
#  '1352.hdf5': -0.1494394237973303,
#  '1353.hdf5': -0.14643267670725463,
#  '1354.hdf5': -0.1520912209034353,
#  '1369.hdf5': -0.15565537126512785,
#  '1370.hdf5': -0.15490796648832544,
#  '1371.hdf5': -0.14803335064547393,
#  '1373.hdf5': -0.14760991580230523,
#  '1376.hdf5': -0.11961900852754573,
#  '1379.hdf5': -0.11456024311348925,
#  '1382.hdf5': -0.15586312523695744,
#  '1384.hdf5': -0.14062997587490372,
#  '1385.hdf5': -0.15471094415331174,
#  '1386.hdf5': -0.15182719901377614,
#  '1387.hdf5': -0.14993437150092825,
#  '1388.hdf5': -0.1554331483149523,
#  '1400.hdf5': -0.154151873790646,
#  '1404.hdf5': -0.15032285130053366,
#  '1408.hdf5': -0.14023000746664332,
#  '1409.hdf5': -0.14669737416402107,
#  '141.hdf5': -0.1475700957753025,
#  '1411.hdf5': -0.15567647591804226,
#  '1412.hdf5': -0.14893830069759345,
#  '1414.hdf5': -0.1550208495385813,
#  '1415.hdf5': -0.15575053589951168,
#  '1416.hdf5': -0.14952663103345418,
#  '1417.hdf5': -0.15572993820479045,
#  '1419.hdf5': -0.15565498855596524,
#  '1420.hdf5': -0.14832597396187305,
#  '1421.hdf5': -0.14345510467052855,
#  '1422.hdf5': -0.15504265695519773,
#  '1423.hdf5': -0.15209107856431964,
#  '1438.hdf5': -0.14893239576488337,
#  '1439.hdf5': -0.14611054536094192,
#  '1440.hdf5': -0.15567545557746695,
#  '1446.hdf5': -0.15475749364760324,
#  '1447.hdf5': -0.15519246761204383,
#  '1454.hdf5': -0.14053501328853313,
#  '1455.hdf5': -0.1548897992590569,
#  '1456.hdf5': -0.0834698035392844,
#  '1457.hdf5': -0.15477565513488875,
#  '148.hdf5': -0.14668968353138734,
#  '152.hdf5': -0.15560871198411313,
#  '156.hdf5': -0.1434774381024575,
#  '159.hdf5': -0.15388016550973843,
#  '16.hdf5': -0.15603072691401426,
#  '160.hdf5': -0.15484777055781132,
#  '162.hdf5': -0.15588017413181215,
#  '166.hdf5': -0.1404440212870477,
#  '167.hdf5': -0.14669439326024686,
#  '168.hdf5': -0.1492351012774936,
#  '183.hdf5': -0.15585953991996715,
#  '184.hdf5': -0.15421785971433333,
#  '186.hdf5': -0.15475023239062483,
#  '187.hdf5': -0.14844744414944686,
#  '190.hdf5': -0.1556499476768024,
#  '191.hdf5': -0.14780385769075433,
#  '194.hdf5': -0.11883344708007826,
#  '196.hdf5': -0.14866947132966213,
#  '201.hdf5': -0.15434411727390843,
#  '21.hdf5': -0.14803454080679304,
#  '220.hdf5': -0.14344337712154184,
#  '223.hdf5': -0.15487764234876034,
#  '224.hdf5': -0.15487633843746296,
#  '229.hdf5': -0.15567261872985774,
#  '232.hdf5': -0.15569145495643996,
#  '233.hdf5': -0.14877015223881393,
#  '234.hdf5': -0.14956263176315593,
#  '235.hdf5': -0.14959385979269973,
#  '238.hdf5': -0.14926285246901855,
#  '243.hdf5': -0.15566966823690676,
#  '249.hdf5': -0.14953520934160763,
#  '250.hdf5': -0.149324865196515,
#  '255.hdf5': -0.15111494243571097,
#  '257.hdf5': -0.15560590012023923,
#  '258.hdf5': -0.14279448054609892,
#  '260.hdf5': -0.14259804888189342,
#  '262.hdf5': -0.15484099091270317,
#  '266.hdf5': -0.1699938663285087,
#  '267.hdf5': -0.15546332246016023,
#  '272.hdf5': -0.15289872866759827,
#  '273.hdf5': -0.15217327822374707,
#  '275.hdf5': -0.14877015704092186,
#  '276.hdf5': -0.15010596798533674,
#  '289.hdf5': -0.15113017880645557,
#  '291.hdf5': -0.1487887425404911,
#  '292.hdf5': -0.14862288187918402,
#  '294.hdf5': -0.1558490240919647,
#  '295.hdf5': -0.15508192875938012,
#  '296.hdf5': -0.15435621472510255,
#  '297.hdf5': -0.1547909622648232,
#  '299.hdf5': -0.15438984342715084,
#  '300.hdf5': -0.12505821458830413,
#  '301.hdf5': -0.15288772509413504,
#  '302.hdf5': -0.15150145896474257,
#  '304.hdf5': -0.15475520567942705,
#  '306.hdf5': -0.1418587679237645,
#  '307.hdf5': -0.15459699809170854,
#  '308.hdf5': -0.14928507137758495,
#  '309.hdf5': -0.15202055444225826,
#  '311.hdf5': -0.14942864941827608,
#  '312.hdf5': -0.15446937944643627,
#  '32.hdf5': -0.15565517553182387,
#  '326.hdf5': -0.12271032325720599,
#  '327.hdf5': -0.152177505266252,
#  '341.hdf5': -0.1489403933129083,
#  '342.hdf5': -0.14811839703532428,
#  '345.hdf5': -0.14945610783026547,
#  '347.hdf5': -0.1401164894493356,
#  '356.hdf5': -0.15481322291703362,
#  '361.hdf5': -0.15212147947276133,
#  '363.hdf5': -0.1549487537280425,
#  '364.hdf5': -0.15014273492160066,
#  '368.hdf5': -0.14297469061468346,
#  '372.hdf5': -0.15566060910556237,
#  '373.hdf5': -0.14991381391470224,
#  '374.hdf5': -0.14240127312582204,
#  '375.hdf5': -0.1549021004741323,
#  '376.hdf5': -0.14986127866997656,
#  '377.hdf5': -0.15206438501596678,
#  '378.hdf5': -0.14936909875028112,
#  '381.hdf5': -0.1430245226709933,
#  '382.hdf5': -0.14920583827229447,
#  '383.hdf5': -0.15592801115519198,
#  '386.hdf5': -0.14981939344304293,
#  '395.hdf5': -0.13303404354427753,
#  '396.hdf5': -0.14568522006444762,
#  '397.hdf5': -0.1544399413438108,
#  '398.hdf5': -0.15142934472107808,
#  '399.hdf5': -0.15164902951479198,
#  '400.hdf5': -0.15199512089598377,
#  '401.hdf5': -0.14629136440600354,
#  '402.hdf5': -0.15448822595303385,
#  '403.hdf5': -0.15481267912372185,
#  '406.hdf5': -0.14872359033719654,
#  '408.hdf5': -0.14629247056690173,
#  '411.hdf5': -0.15225027449643802,
#  '412.hdf5': -0.15518237458430503,
#  '413.hdf5': -0.14822058015693892,
#  '415.hdf5': -0.15145261140966393,
#  '416.hdf5': -0.1429602574498581,
#  '417.hdf5': -0.15570572037228333,
#  '422.hdf5': -0.15584093646402333,
#  '423.hdf5': -0.14304635423106182,
#  '428.hdf5': -0.14894276486596453,
#  '431.hdf5': -0.1482113228133413,
#  '432.hdf5': -0.15009555380599066,
#  '433.hdf5': -0.15623723379868687,
#  '443.hdf5': -0.14786573021085442,
#  '446.hdf5': -0.15162041513037525,
#  '447.hdf5': -0.15495307527101293,
#  '449.hdf5': -0.1495894993281881,
#  '450.hdf5': -0.15226460431318808,
#  '452.hdf5': -0.15480293866692596,
#  '455.hdf5': -0.14930122637148638,
#  '456.hdf5': -0.14943331553926983,
#  '459.hdf5': -0.14654576154130267,
#  '46.hdf5': -0.15568638892532863,
#  '460.hdf5': -0.14248467610036913,
#  '461.hdf5': -0.15598692512735332,
#  '468.hdf5': -0.15286753104663767,
#  '470.hdf5': -0.1557368559528431,
#  '473.hdf5': -0.14669635019184588,
#  '475.hdf5': -0.15487960260147376,
#  '477.hdf5': -0.15567429884055967,
#  '479.hdf5': -0.1548089343263726,
#  '48.hdf5': -0.14892530909298451,
#  '484.hdf5': -0.14725360344746652,
#  '485.hdf5': -0.15547618545600808,
#  '486.hdf5': -0.14308008032703232,
#  '494.hdf5': -0.14785191453869317,
#  '496.hdf5': -0.1467123192796898,
#  '50.hdf5': -0.1557405799783708,
#  '504.hdf5': -0.14675045315040888,
#  '505.hdf5': -0.15474396363390053,
#  '508.hdf5': -0.155487471079088,
#  '509.hdf5': -0.1551397569836987,
#  '512.hdf5': -0.14863711193559898,
#  '514.hdf5': -0.15191221771892222,
#  '515.hdf5': -0.14886725044957472,
#  '517.hdf5': -0.1482514325633154,
#  '518.hdf5': -0.14874194859201523,
#  '519.hdf5': -0.15195109530860543,
#  '520.hdf5': -0.15209281964628962,
#  '527.hdf5': -0.15535938330257337,
#  '529.hdf5': -0.15212296601864464,
#  '530.hdf5': -0.15489247455850835,
#  '531.hdf5': -0.15559750755818763,
#  '537.hdf5': -0.14181596340702163,
#  '539.hdf5': -0.15391170584352726,
#  '541.hdf5': -0.1509306231618031,
#  '55.hdf5': -0.15286560037767483,
#  '551.hdf5': -0.15607207504770013,
#  '552.hdf5': -0.15017086600782764,
#  '553.hdf5': -0.15487379119961925,
#  '554.hdf5': -0.16865428099775814,
#  '56.hdf5': -0.1491566627029614,
#  '566.hdf5': -0.14925779499337322,
#  '568.hdf5': -0.14581054459581208,
#  '569.hdf5': -0.1440819556659925,
#  '571.hdf5': -0.15490789178435171,
#  '574.hdf5': -0.14311319602276612,
#  '575.hdf5': -0.14856702477022524,
#  '576.hdf5': -0.15565494072276398,
#  '578.hdf5': -0.1491818933868658,
#  '58.hdf5': -0.14951065408772637,
#  '582.hdf5': -0.1495935846092021,
#  '583.hdf5': -0.1543120207046779,
#  '585.hdf5': -0.14683479512448974,
#  '586.hdf5': -0.15475708663187007,
#  '588.hdf5': -0.1444680189377223,
#  '589.hdf5': -0.1558112828729012,
#  '590.hdf5': -0.14937494433174306,
#  '595.hdf5': -0.15553507714879478,
#  '596.hdf5': -0.15110089300413426,
#  '598.hdf5': -0.1495188795876656,
#  '601.hdf5': -0.1460898058237442,
#  '602.hdf5': -0.1483705215313508,
#  '611.hdf5': -0.15564631328959389,
#  '612.hdf5': -0.15492224251461986,
#  '613.hdf5': -0.14945231633312617,
#  '614.hdf5': -0.1541526784955966,
#  '617.hdf5': -0.14864674391459687,
#  '618.hdf5': -0.14882730006531358,
#  '619.hdf5': -0.1483462564304923,
#  '620.hdf5': -0.1521045387711477,
#  '621.hdf5': -0.12026262269853452,
#  '622.hdf5': -0.1491774096277725,
#  '623.hdf5': -0.14540146027591963,
#  '624.hdf5': -0.14865794143906078,
#  '633.hdf5': -0.14819415085880455,
#  '635.hdf5': -0.1460463848796996,
#  '636.hdf5': -0.15214254814527112,
#  '639.hdf5': -0.1406456505280801,
#  '648.hdf5': -0.15605098883329588,
#  '649.hdf5': -0.15494379472611428,
#  '653.hdf5': -0.14251322262965782,
#  '654.hdf5': -0.1437634363064728,
#  '655.hdf5': -0.1488953899139609,
#  '656.hdf5': -0.1541200303746401,
#  '657.hdf5': -0.14828185546285594,
#  '658.hdf5': -0.1562067391094283,
#  '66.hdf5': -0.14928192625189501,
#  '671.hdf5': -0.15611557534107212,
#  '672.hdf5': -0.1557846682047123,
#  '676.hdf5': -0.1521317215478644,
#  '677.hdf5': -0.1868289844960413,
#  '680.hdf5': -0.1555024200400972,
#  '681.hdf5': -0.15538898221735792,
#  '682.hdf5': -0.14923359148997337,
#  '683.hdf5': -0.1500892889066381,
#  '687.hdf5': -0.15534516060023518,
#  '690.hdf5': -0.1555871821058826,
#  '691.hdf5': -0.14843858130979395,
#  '692.hdf5': -0.14922036154942558,
#  '700.hdf5': -0.15458792669643645,
#  '706.hdf5': -0.1489585945694705,
#  '709.hdf5': -0.1518728341571714,
#  '710.hdf5': -0.1427894962497669,
#  '712.hdf5': -0.15196491357113528,
#  '713.hdf5': -0.15587362285049272,
#  '717.hdf5': -0.1493283650090371,
#  '720.hdf5': -0.14014759100394739,
#  '723.hdf5': -0.14295143635742819,
#  '724.hdf5': -0.15161489524385383,
#  '725.hdf5': -0.15566592903291998,
#  '726.hdf5': -0.14305681038557472,
#  '727.hdf5': -0.15228518201761695,
#  '738.hdf5': -0.1558416343233256,
#  '741.hdf5': -0.14047140827521334,
#  '744.hdf5': -0.15399691143424402,
#  '747.hdf5': -0.1485483354417631,
#  '749.hdf5': -0.14184414342662047,
#  '750.hdf5': -0.1494263020918987,
#  '751.hdf5': -0.1495302710909276,
#  '752.hdf5': -0.14806417190463533,
#  '753.hdf5': -0.15464150096775758,
#  '754.hdf5': -0.15616710461740865,
#  '756.hdf5': -0.1334115604510479,
#  '757.hdf5': -0.15564901906346365,
#  '758.hdf5': -0.15422310147409007,
#  '759.hdf5': -0.14776706647858212,
#  '760.hdf5': -0.1405262782921255,
#  '762.hdf5': -0.15565876644745283,
#  '771.hdf5': -0.15420878936511262,
#  '775.hdf5': -0.1547133143714621,
#  '781.hdf5': -0.15476860498141792,
#  '782.hdf5': -0.1495578182745838,
#  '783.hdf5': -0.1520466277064708,
#  '785.hdf5': -0.155319051073734,
#  '786.hdf5': -0.14949203215635654,
#  '788.hdf5': -0.1412273886800737,
#  '789.hdf5': -0.15569766459065254,
#  '79.hdf5': -0.14897247153877144,
#  '790.hdf5': -0.12618871968227996,
#  '791.hdf5': -0.14949562282786763,
#  '792.hdf5': -0.15451217006118403,
#  '793.hdf5': -0.1492005120316606,
#  '794.hdf5': -0.15531151384741676,
#  '795.hdf5': -0.15284858689879358,
#  '796.hdf5': -0.1478918013907009,
#  '797.hdf5': -0.1500938430004518,
#  '806.hdf5': -0.15560263423848272,
#  '81.hdf5': -0.15480788589113553,
#  '813.hdf5': -0.1544129698100597,
#  '817.hdf5': -0.15218818010820628,
#  '818.hdf5': -0.14969646441317375,
#  '824.hdf5': -0.15473352042401425,
#  '825.hdf5': -0.15491679086432897,
#  '826.hdf5': -0.15490587694884317,
#  '827.hdf5': -0.1486509627275801,
#  '828.hdf5': -0.15440880329834203,
#  '829.hdf5': -0.1490308782515071,
#  '830.hdf5': -0.15547462975517934,
#  '831.hdf5': -0.147093651241456,
#  '832.hdf5': -0.1510051503061282,
#  '840.hdf5': -0.14896224560837096,
#  '844.hdf5': -0.12347764998742336,
#  '846.hdf5': -0.14666957553461385,
#  '847.hdf5': -0.14902958994599033,
#  '85.hdf5': -0.1553205518969467,
#  '850.hdf5': -0.15536293995844203,
#  '852.hdf5': -0.14864433371460556,
#  '853.hdf5': -0.15220467936614687,
#  '854.hdf5': -0.15556629031279745,
#  '86.hdf5': -0.15598296829650557,
#  '861.hdf5': -0.14965248359592248,
#  '862.hdf5': -0.14933791648293412,
#  '863.hdf5': -0.15008947445384851,
#  '864.hdf5': -0.147400596058771,
#  '865.hdf5': -0.1541486498621517,
#  '866.hdf5': -0.15470317215985496,
#  '867.hdf5': -0.14914076298360923,
#  '87.hdf5': -0.1405383100365056,
#  '880.hdf5': -0.1556391191304004,
#  '881.hdf5': -0.1557339158773276,
#  '885.hdf5': -0.14395796199181043,
#  '886.hdf5': -0.14783643768620258,
#  '888.hdf5': -0.1559484142790501,
#  '889.hdf5': -0.1520407185682293,
#  '890.hdf5': -0.14614959123161933,
#  '893.hdf5': -0.14799211698593923,
#  '895.hdf5': -0.15562001715567486,
#  '897.hdf5': -0.14403598411121085,
#  '898.hdf5': -0.14847190938091856,
#  '899.hdf5': -0.15128805354013222,
#  '900.hdf5': -0.12135123173709875,
#  '901.hdf5': -0.15139705607963158,
#  '903.hdf5': -0.1548233199403017,
#  '91.hdf5': -0.1561145865064905,
#  '910.hdf5': -0.11985809933458708,
#  '914.hdf5': -0.15100700281330173,
#  '915.hdf5': -0.1465982975030076,
#  '917.hdf5': -0.15563414470925624,
#  '918.hdf5': -0.15598855538334824,
#  '920.hdf5': -0.14963943171803537,
#  '921.hdf5': -0.15620304828721127,
#  '922.hdf5': -0.1547828858527467,
#  '923.hdf5': -0.14230430055336082,
#  '924.hdf5': -0.15475563637007964,
#  '925.hdf5': -0.1490049161894826,
#  '926.hdf5': -0.1522519378656177,
#  '927.hdf5': -0.15559603580149373,
#  '928.hdf5': -0.15155434088053985,
#  '929.hdf5': -0.14810481233087588,
#  '93.hdf5': -0.14894078515625228,
#  '930.hdf5': -0.15013990456016937,
#  '931.hdf5': -0.15613392554102276,
#  '932.hdf5': -0.15568770656025788,
#  '933.hdf5': -0.1521563544967985,
#  '934.hdf5': -0.14854698798226937,
#  '935.hdf5': -0.13981781454085773,
#  '936.hdf5': -0.14109981259309878,
#  '937.hdf5': -0.15550701500618974,
#  '955.hdf5': -0.1403389354582661,
#  '956.hdf5': -0.1511054765832854,
#  '957.hdf5': -0.1554966068801782,
#  '958.hdf5': -0.15585715288178104,
#  '959.hdf5': -0.18846307092030856,
#  '96.hdf5': -0.155794032129801,
#  '960.hdf5': -0.15145388907662818,
#  '964.hdf5': -0.1555576502861669,
#  '965.hdf5': -0.15213005817176015,
#  '966.hdf5': -0.1487801723411121,
#  '967.hdf5': -0.1473687645722301,
#  '968.hdf5': -0.13483014762783901,
#  '969.hdf5': -0.1483209135490401,
#  '970.hdf5': -0.14586811064063446,
#  '971.hdf5': -0.15570581004515077,
#  '972.hdf5': -0.1546494920759168,
#  '973.hdf5': -0.15541466655603292,
#  '980.hdf5': -0.15585036601302976,
#  '982.hdf5': -0.15595590893655603,
#  '984.hdf5': -0.1548254977617078,
#  '985.hdf5': -0.14938307951769914,
#  '986.hdf5': -0.1478005880271867,
#  '987.hdf5': -0.15568436488645612,
#  '988.hdf5': -0.1557192095775857,
#  '990.hdf5': -0.15622014466979137,
#  '991.hdf5': -0.15406756799268898,
#  '993.hdf5': -0.1547634815013204,
#  '999.hdf5': -0.1528987980759359}
